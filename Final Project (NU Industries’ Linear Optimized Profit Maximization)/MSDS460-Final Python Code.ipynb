# %%
pip install pulp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.3 MB 4.7 MB/s
# ...

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize
import pandas as pd

# %%
# Period 1 Widgets 
W_1_A_R_N = LpVariable("W_1_A_R_N", 0, None)
W_1_A_R_S = LpVariable("W_1_A_R_S", 0, None)
W_1_A_O_N = LpVariable("W_1_A_O_N", 0, None)
W_1_A_O_S = LpVariable("W_1_A_O_S", 0, None)
W_1_B_R_N = LpVariable("W_1_B_R_N", 0, None)
W_1_B_R_S = LpVariable("W_1_B_R_S", 0, None)
W_1_B_O_N = LpVariable("W_1_B_O_N", 0, None)
W_1_B_O_S = LpVariable("W_1_B_O_S", 0, None)

# Period 2 Widgets
W_2_A_R_N = LpVariable("W_2_A_R_N", 0, None)
W_2_A_R_S = LpVariable("W_2_A_R_S", 0, None)
W_2_A_O_N = LpVariable("W_2_A_O_N", 0, None)
W_2_A_O_S = LpVariable("W_2_A_O_S", 0, None)
W_2_B_R_N = LpVariable("W_2_B_R_N", 0, None)
W_2_B_R_S = LpVariable("W_2_B_R_S", 0, None)
W_2_B_O_N = LpVariable("W_2_B_O_N", 0, None)
W_2_B_O_S = LpVariable("W_2_B_O_S", 0, None)

# Period 3 Widgets
W_3_A_R_N = LpVariable("W_3_A_R_N", 0, None)
W_3_A_R_S = LpVariable("W_3_A_R_S", 0, None)
W_3_A_O_N = LpVariable("W_3_A_O_N", 0, None)
W_3_A_O_S = LpVariable("W_3_A_O_S", 0, None)
W_3_B_R_N = LpVariable("W_3_B_R_N", 0, None)
W_3_B_R_S = LpVariable("W_3_B_R_S", 0, None)
W_3_B_O_N = LpVariable("W_3_B_O_N", 0, None)
W_3_B_O_S = LpVariable("W_3_B_O_S", 0, None)

# Period 4 Widgets
W_4_A_R_N = LpVariable("W_4_A_R_N", 0, None)
W_4_A_R_S = LpVariable("W_4_A_R_S", 0, None)
W_4_A_O_N = LpVariable("W_4_A_O_N", 0, None)
W_4_A_O_S = LpVariable("W_4_A_O_S", 0, None)
W_4_B_R_N = LpVariable("W_4_B_R_N", 0, None)
W_4_B_R_S = LpVariable("W_4_B_R_S", 0, None)
W_4_B_O_N = LpVariable("W_4_B_O_N", 0, None)
W_4_B_O_S = LpVariable("W_4_B_O_S", 0, None)

# Period 5 Widgets
W_5_A_R_N = LpVariable("W_5_A_R_N", 0, None)
W_5_A_O_N = LpVariable("W_5_A_O_N", 0, None)
W_5_B_R_N = LpVariable("W_5_B_R_N", 0, None)
W_5_B_O_N = LpVariable("W_5_B_O_N", 0, None)

# Period 1 Gadgets
G_1_A_R_N = LpVariable("G_1_A_R_N", 0, None)
G_1_A_R_S = LpVariable("G_1_A_R_S", 0, None)
G_1_A_O_N = LpVariable("G_1_A_O_N", 0, None)
G_1_A_O_S = LpVariable("G_1_A_O_S", 0, None)
G_1_B_R_N = LpVariable("G_1_B_R_N", 0, None)
G_1_B_R_S = LpVariable("G_1_B_R_S", 0, None)
G_1_B_O_N = LpVariable("G_1_B_O_N", 0, None)
G_1_B_O_S = LpVariable("G_1_B_O_S", 0, None)

# Period 2 Gadgets
G_2_A_R_N = LpVariable("G_2_A_R_N", 0, None)
G_2_A_R_S = LpVariable("G_2_A_R_S", 0, None)
G_2_A_O_N = LpVariable("G_2_A_O_N", 0, None)
G_2_A_O_S = LpVariable("G_2_A_O_S", 0, None)
G_2_B_R_N = LpVariable("G_2_B_R_N", 0, None)
G_2_B_R_S = LpVariable("G_2_B_R_S", 0, None)
G_2_B_O_N = LpVariable("G_2_B_O_N", 0, None)
G_2_B_O_S = LpVariable("G_2_B_O_S", 0, None)

# Period 3 Gadgets
G_3_A_R_N = LpVariable("G_3_A_R_N", 0, None)
G_3_A_R_S = LpVariable("G_3_A_R_S", 0, None)
G_3_A_O_N = LpVariable("G_3_A_O_N", 0, None)
G_3_A_O_S = LpVariable("G_3_A_O_S", 0, None)
G_3_B_R_N = LpVariable("G_3_B_R_N", 0, None)
G_3_B_R_S = LpVariable("G_3_B_R_S", 0, None)
G_3_B_O_N = LpVariable("G_3_B_O_N", 0, None)
G_3_B_O_S = LpVariable("G_3_B_O_S", 0, None)

# Period 4 Gadgets
G_4_A_R_N = LpVariable("G_4_A_R_N", 0, None)
G_4_A_R_S = LpVariable("G_4_A_R_S", 0, None)
G_4_A_O_N = LpVariable("G_4_A_O_N", 0, None)
G_4_A_O_S = LpVariable("G_4_A_O_S", 0, None)
G_4_B_R_N = LpVariable("G_4_B_R_N", 0, None)
G_4_B_R_S = LpVariable("G_4_B_R_S", 0, None)
G_4_B_O_N = LpVariable("G_4_B_O_N", 0, None)
G_4_B_O_S = LpVariable("G_4_B_O_S", 0, None)

# Period 5 Gadgets
G_5_A_R_N = LpVariable("G_5_A_R_N", 0, None)
G_5_A_O_N = LpVariable("G_5_A_O_N", 0, None)
G_5_B_R_N = LpVariable("G_5_B_R_N", 0, None)
G_5_B_O_N = LpVariable("G_5_B_O_N", 0, None)

# Period 1 Flugels
F_1_A_R_N = LpVariable("F_1_A_R_N", 0, None)
F_1_A_R_S = LpVariable("F_1_A_R_S", 0, None)
F_1_A_O_N = LpVariable("F_1_A_O_N", 0, None)
F_1_A_O_S = LpVariable("F_1_A_O_S", 0, None)
F_1_B_R_N = LpVariable("F_1_B_R_N", 0, None)
F_1_B_R_S = LpVariable("F_1_B_R_S", 0, None)
F_1_B_O_N = LpVariable("F_1_B_O_N", 0, None)
F_1_B_O_S = LpVariable("F_1_B_O_S", 0, None)

# Period 2 Flugels
F_2_A_R_N = LpVariable("F_2_A_R_N", 0, None)
F_2_A_R_S = LpVariable("F_2_A_R_S", 0, None)
F_2_A_O_N = LpVariable("F_2_A_O_N", 0, None)
F_2_A_O_S = LpVariable("F_2_A_O_S", 0, None)
F_2_B_R_N = LpVariable("F_2_B_R_N", 0, None)
F_2_B_R_S = LpVariable("F_2_B_R_S", 0, None)
F_2_B_O_N = LpVariable("F_2_B_O_N", 0, None)
F_2_B_O_S = LpVariable("F_2_B_O_S", 0, None)

# Period 3 Flugels
F_3_A_R_N = LpVariable("F_3_A_R_N", 0, None)
F_3_A_R_S = LpVariable("F_3_A_R_S", 0, None)
F_3_A_O_N = LpVariable("F_3_A_O_N", 0, None)
F_3_A_O_S = LpVariable("F_3_A_O_S", 0, None)
F_3_B_R_N = LpVariable("F_3_B_R_N", 0, None)
F_3_B_R_S = LpVariable("F_3_B_R_S", 0, None)
F_3_B_O_N = LpVariable("F_3_B_O_N", 0, None)
F_3_B_O_S = LpVariable("F_3_B_O_S", 0, None)

# Period 4 Flugels
F_4_A_R_N = LpVariable("F_4_A_R_N", 0, None)
F_4_A_R_S = LpVariable("F_4_A_R_S", 0, None)
F_4_A_O_N = LpVariable("F_4_A_O_N", 0, None)
F_4_A_O_S = LpVariable("F_4_A_O_S", 0, None)
F_4_B_R_N = LpVariable("F_4_B_R_N", 0, None)
F_4_B_R_S = LpVariable("F_4_B_R_S", 0, None)
F_4_B_O_N = LpVariable("F_4_B_O_N", 0, None)
F_4_B_O_S = LpVariable("F_4_B_O_S", 0, None)

# Period 5 Flugels
F_5_A_R_N = LpVariable("F_5_A_R_N", 0, None)
F_5_A_O_N = LpVariable("F_5_A_O_N", 0, None)
F_5_B_R_N = LpVariable("F_5_B_R_N", 0, None)
F_5_B_O_N = LpVariable("F_5_B_O_N", 0, None)

# Units from advertising/marketing
W_1_K = LpVariable("W_1_K", 0, None)
W_2_K = LpVariable("W_2_K", 0, None)
W_3_K = LpVariable("W_3_K", 0, None)
W_4_K = LpVariable("W_4_K", 0, None)
G_1_K = LpVariable("G_1_K", 0, None)
G_2_K = LpVariable("G_2_K", 0, None)
G_3_K = LpVariable("G_3_K", 0, None)
G_4_K = LpVariable("G_4_K", 0, None)
F_1_K = LpVariable("F_1_K", 0, None)
F_2_K = LpVariable("F_2_K", 0, None)
F_3_K = LpVariable("F_3_K", 0, None)
F_4_K = LpVariable("F_4_K", 0, None)

# %%
prob = LpProblem("problem", LpMaximize)

# %%
# widget demand (# units)
prob += W_1_A_R_N + W_1_A_O_N + W_1_B_R_N + W_1_B_O_N == 70
prob += W_1_A_R_S + W_1_A_O_S + W_1_B_R_S + W_1_B_O_S + W_2_A_R_N + W_2_A_O_N + W_2_B_R_N + W_2_B_O_N == 125 + W_1_K
prob += W_2_A_R_S + W_2_A_O_S + W_2_B_R_S + W_2_B_O_S + W_3_A_R_N + W_3_A_O_N + W_3_B_R_N + W_3_B_O_N == 185 + W_2_K
prob += W_3_A_R_S + W_3_A_O_S + W_3_B_R_S + W_3_B_O_S + W_4_A_R_N + W_4_A_O_N + W_4_B_R_N + W_4_B_O_N == 190 + W_3_K
prob += W_4_A_R_S + W_4_A_O_S + W_4_B_R_S + W_4_B_O_S + W_5_A_R_N + W_5_A_O_N + W_5_B_R_N + W_5_B_O_N == 200 + W_4_K

# gadget demand (# units)
prob += G_1_A_R_N + G_1_A_O_N + G_1_B_R_N + G_1_B_O_N == 200
prob += G_1_A_R_S + G_1_A_O_S + G_1_B_R_S + G_1_B_O_S + G_2_A_R_N + G_2_A_O_N + G_2_B_R_N + G_2_B_O_N == 300 + G_1_K
prob += G_2_A_R_S + G_2_A_O_S + G_2_B_R_S + G_2_B_O_S + G_3_A_R_N + G_3_A_O_N + G_3_B_R_N + G_3_B_O_N == 295 + G_2_K
prob += G_3_A_R_S + G_3_A_O_S + G_3_B_R_S + G_3_B_O_S + G_4_A_R_N + G_4_A_O_N + G_4_B_R_N + G_4_B_O_N == 245 + G_3_K
prob += G_4_A_R_S + G_4_A_O_S + G_4_B_R_S + G_4_B_O_S + G_5_A_R_N + G_5_A_O_N + G_5_B_R_N + G_5_B_O_N == 240 + G_4_K

# flugels demand (# units)
prob += F_1_A_R_N + F_1_A_O_N + F_1_B_R_N + F_1_B_O_N == 140
prob += F_1_A_R_S + F_1_A_O_S + F_1_B_R_S + F_1_B_O_S + F_2_A_R_N + F_2_A_O_N + F_2_B_R_N + F_2_B_O_N == 175 + F_1_K
prob += F_2_A_R_S + F_2_A_O_S + F_2_B_R_S + F_2_B_O_S + F_3_A_R_N + F_3_A_O_N + F_3_B_R_N + F_3_B_O_N == 205 + F_2_K
prob += F_3_A_R_S + F_3_A_O_S + F_3_B_R_S + F_3_B_O_S + F_4_A_R_N + F_4_A_O_N + F_4_B_R_N + F_4_B_O_N == 235 + F_3_K
prob += F_4_A_R_S + F_4_A_O_S + F_4_B_R_S + F_4_B_O_S + F_5_A_R_N + F_5_A_O_N + F_5_B_R_N + F_5_B_O_N == 230 + F_4_K

# marketing budget ($)
prob += 160*( W_1_K + W_2_K + W_3_K + W_4_K ) + 120*( G_1_K + G_2_K + G_3_K + G_4_K ) + 180*( F_1_K + F_2_K + F_3_K + F_4_K ) <= 70000

# raw material 1 constraint (lbs.)
prob += 194*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S ) + 230*( G_1_A_R_N + G_1_A_R_S + G_1_A_O_N + G_1_A_O_S ) + 178*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S ) + 188*( W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S ) + 225*( G_1_B_R_N + G_1_B_R_S + G_1_B_O_N + G_1_B_O_S ) + 170*( F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S ) <= 140000
prob += 194*( W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S ) + 230*( G_2_A_R_N + G_2_A_R_S + G_2_A_O_N + G_2_A_O_S ) + 178*( F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S ) + 188*( W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S ) + 225*( G_2_B_R_N + G_2_B_R_S + G_2_B_O_N + G_2_B_O_S ) + 170*( F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S ) <= 140000
prob += 194*( W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S ) + 230*( G_3_A_R_N + G_3_A_R_S + G_3_A_O_N + G_3_A_O_S ) + 178*( F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S ) + 188*( W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S ) + 225*( G_3_B_R_N + G_3_B_R_S + G_3_B_O_N + G_3_B_O_S ) + 170*( F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S ) <= 140000
prob += 194*( W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S ) + 230*( G_4_A_R_N + G_4_A_R_S + G_4_A_O_N + G_4_A_O_S ) + 178*( F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S ) + 188*( W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S ) + 225*( G_4_B_R_N + G_4_B_R_S + G_4_B_O_N + G_4_B_O_S ) + 170*( F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S ) <= 140000
prob += 194*( W_5_A_R_N + W_5_A_O_N ) + 230*( G_5_A_R_N+ G_5_A_O_N ) + 178*( F_5_A_R_N + F_5_A_O_N ) + 188*( W_5_B_R_N + W_5_B_O_N ) + 225*( G_5_B_R_N + G_5_B_O_N ) + 170*( F_5_B_R_N + F_5_B_O_N ) <= 140000

# raw material 2 constraint (lbs.)
prob += 8.6*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S ) + 11.6*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S ) + 9.2*( W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S ) + 10.8*( F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S ) <= 5000
prob += 8.6*( W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S ) + 11.6*( F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S ) + 9.2*( W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S ) + 10.8*( F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S ) <= 5000
prob += 8.6*( W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S ) + 11.6*( F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S ) + 9.2*( W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S ) + 10.8*( F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S ) <= 5000
prob += 8.6*( W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S ) + 11.6*( F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S ) + 9.2*( W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S ) + 10.8*( F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S ) <= 5000
prob += 8.6*( W_5_A_R_N + W_5_A_O_N ) + 11.6*( F_5_A_R_N + F_5_A_O_N ) + 9.2*( W_5_B_R_N + W_5_B_O_N ) + 10.8*( F_5_B_R_N + F_5_B_O_N ) <= 5000

# plant A labor constraints (hours)
prob += 9.5*( W_1_A_R_N + W_1_A_R_S ) + 7.1*( G_1_A_R_N + G_1_A_R_S ) + 11.1*( F_1_A_R_N + F_1_A_R_S ) <= 2500
prob += 9.5*( W_2_A_R_N + W_2_A_R_S ) + 7.1*( G_2_A_R_N + G_2_A_R_S ) + 11.1*( F_2_A_R_N + F_2_A_R_S ) <= 2500
prob += 9.5*( W_3_A_R_N + W_3_A_R_S ) + 7.1*( G_3_A_R_N + G_3_A_R_S ) + 11.1*( F_3_A_R_N + F_3_A_R_S ) <= 2500
prob += 9.5*( W_4_A_R_N + W_4_A_R_S ) + 7.1*( G_4_A_R_N + G_4_A_R_S ) + 11.1*( F_4_A_R_N + F_4_A_R_S ) <= 2500
prob += 9.5*( W_5_A_R_N ) + 7.1*( G_5_A_R_N ) + 11.1*( F_5_A_R_N ) <= 2500

# plant B labor constraints (hours)
prob += 9.1*( W_1_B_R_N + W_1_B_R_S ) + 7.8*( G_1_B_R_N + G_1_B_R_S ) + 10.6*( F_1_B_R_N + F_1_B_R_S ) <= 3800
prob += 9.1*( W_2_B_R_N + W_2_B_R_S ) + 7.8*( G_2_B_R_N + G_2_B_R_S ) + 10.6*( F_2_B_R_N + F_2_B_R_S ) <= 3800
prob += 9.1*( W_3_B_R_N + W_3_B_R_S ) + 7.8*( G_3_B_R_N + G_3_B_R_S ) + 10.6*( F_3_B_R_N + F_3_B_R_S ) <= 3800
prob += 9.1*( W_4_B_R_N + W_4_B_R_S ) + 7.8*( G_4_B_R_N + G_4_B_R_S ) + 10.6*( F_4_B_R_N + F_4_B_R_S ) <= 3800
prob += 9.1*( W_5_B_R_N ) + 7.8*( G_5_B_R_N ) + 10.6*( F_5_B_R_N ) <= 3800

# plant A storage constraints (# units)
prob += ( W_1_A_R_S + W_1_A_O_S + G_1_A_R_S + G_1_A_O_S + F_1_A_R_S + F_1_A_O_S ) <= 70
prob += ( W_2_A_R_S + W_2_A_O_S + G_2_A_R_S + G_2_A_O_S + F_2_A_R_S + F_2_A_O_S ) <= 70
prob += ( W_3_A_R_S + W_3_A_O_S + G_3_A_R_S + G_3_A_O_S + F_3_A_R_S + F_3_A_O_S ) <= 70
prob += ( W_4_A_R_S + W_4_A_O_S + G_4_A_R_S + G_4_A_O_S + F_4_A_R_S + F_4_A_O_S ) <= 70

# plant B storage constraints (# units)
prob += ( W_1_B_R_S + W_1_B_O_S + G_1_B_R_S + G_1_B_O_S + F_1_B_R_S + F_1_B_O_S ) <= 50
prob += ( W_2_B_R_S + W_2_B_O_S + G_2_B_R_S + G_2_B_O_S + F_2_B_R_S + F_2_B_O_S ) <= 50
prob += ( W_3_B_R_S + W_3_B_O_S + G_3_B_R_S + G_3_B_O_S + F_3_B_R_S + F_3_B_O_S ) <= 50
prob += ( W_4_B_R_S + W_4_B_O_S + G_4_B_R_S + G_4_B_O_S + F_4_B_R_S + F_4_B_O_S ) <= 50

# %%
prob += (
    # widget revenue
    + 2490*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S + W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S + W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S + W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S + W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S + W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S + W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S + W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S + W_5_A_R_N + W_5_A_O_N + W_5_B_R_N + W_5_B_O_N )
    # gadget revenue
    + 1990*( G_1_A_R_N + G_1_A_R_S + G_1_A_O_N + G_1_A_O_S + G_1_B_R_N + G_1_B_R_S + G_1_B_O_N + G_1_B_O_S + G_2_A_R_N + G_2_A_R_S + G_2_A_O_N + G_2_A_O_S + G_2_B_R_N + G_2_B_R_S + G_2_B_O_N + G_2_B_O_S + G_3_A_R_N + G_3_A_R_S + G_3_A_O_N + G_3_A_O_S + G_3_B_R_N + G_3_B_R_S + G_3_B_O_N + G_3_B_O_S + G_4_A_R_N + G_4_A_R_S + G_4_A_O_N + G_4_A_O_S + G_4_B_R_N + G_4_B_R_S + G_4_B_O_N + G_4_B_O_S + G_5_A_R_N + G_5_A_O_N + G_5_B_R_N + G_5_B_O_N )
    # flugel revenue
    + 2970*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S + F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S + F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S + F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S + F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S + F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S + F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S + F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S + F_5_A_R_N + F_5_A_O_N + F_5_B_R_N + F_5_B_O_N )
    
    # plant A storage costs (Widgets)
    - 7.50*( W_1_A_R_S + W_1_A_O_S + W_2_A_R_S + W_2_A_O_S + W_3_A_R_S + W_3_A_O_S + W_4_A_R_S + W_4_A_O_S )
    # plant A storage costs (Gadgets)
    - 5.50*( G_1_A_R_S + G_1_A_O_S + G_2_A_R_S + G_2_A_O_S + G_3_A_R_S + G_3_A_O_S + G_4_A_R_S + G_4_A_O_S )
    # plant A storage costs (Flugels)
    - 6.50*( F_1_A_R_S + F_1_A_O_S + F_2_A_R_S + F_2_A_O_S + F_3_A_R_S + F_3_A_O_S + F_4_A_R_S + F_4_A_O_S )
    
    # plant B storage costs (Widgets)
    - 7.80*( W_1_B_R_S + W_1_B_O_S + W_2_B_R_S + W_2_B_O_S + W_3_B_R_S + W_3_B_O_S + W_4_B_R_S + W_4_B_O_S )
    # plant B storage costs (Gadgets)
    - 5.70*( G_1_B_R_S + G_1_B_O_S + G_2_B_R_S + G_2_B_O_S + G_3_B_R_S + G_3_B_O_S + G_4_B_R_S + G_4_B_O_S )
    # plant B storage costs (Flugels)
    - 7.00*( F_1_B_R_S + F_1_B_O_S + F_2_B_R_S + F_2_B_O_S + F_3_B_R_S + F_3_B_O_S + F_4_B_R_S + F_4_B_O_S )
   
    # plant A Regular Labor Cost (Period 1,2)
    - 11.00*( 9.5*(W_1_A_R_N + W_1_A_R_S + W_2_A_R_N + W_2_A_R_S ) +7.1*( G_1_A_R_N + G_1_A_R_S + G_2_A_R_N + G_2_A_R_S ) + 11.1*( F_1_A_R_N + F_1_A_R_S + F_2_A_R_N + F_2_A_R_S ))
    # plant A Regular Labor Cost (5% increase for Period 3,4,5)
    - (11.00*1.05)*(9.5*( W_3_A_R_N + W_3_A_R_S + W_4_A_R_N + W_4_A_R_S + W_5_A_R_N ) +7.1*( G_3_A_R_N + G_3_A_R_S + G_4_A_R_N + G_4_A_R_S + G_5_A_R_N ) + 11.1*( F_3_A_R_N + F_3_A_R_S + F_4_A_R_N + F_4_A_R_S + F_5_A_R_N ))
   
    # plant B Regular Labor Cost (Period 1,2)
    - 11.00*( 9.1*( W_1_B_R_N + W_1_B_R_S + W_2_B_R_N + W_2_B_R_S) +7.8*( G_1_B_R_N + G_1_B_R_S + G_2_B_R_N + G_2_B_R_S ) + 10.6*( F_1_B_R_N + F_1_B_R_S + F_2_B_R_N + F_2_B_R_S ))
    # plant B Regular Labor Cost (10% increase for Period 3,4,5)
    - (11.00*1.1)*(9.1*( W_3_B_R_N + W_3_B_R_S + W_4_B_R_N + W_4_B_R_S + W_5_B_R_N ) + 7.8*( G_3_B_R_N + G_3_B_R_S + G_4_B_R_N + G_4_B_R_S + G_5_B_R_N ) + 10.6*( F_3_B_R_N + F_3_B_R_S + F_4_B_R_N + F_4_B_R_S + F_5_B_R_N ))
  
    # plant A Overtime Labor Cost (Period 1,2)
    - 16.50*(9.5*(  W_1_A_O_N + W_1_A_O_S + W_2_A_O_N + W_2_A_O_S ) + 7.1*( G_1_A_O_N + G_1_A_O_S + G_2_A_O_N + G_2_A_O_S ) + 11.1*( F_1_A_O_N + F_1_A_O_S + F_2_A_O_N + F_2_A_O_S ))
    # plant A Overtime Labor Cost (Period 3,4,5)
    - (16.50*1.05)*(9.5*( W_3_A_O_N + W_3_A_O_S + W_4_A_O_N + W_4_A_O_S + W_5_A_O_N ) + 7.1*( G_3_A_O_N + G_3_A_O_S + G_4_A_O_N + G_4_A_O_S + G_5_A_O_N ) + 11.1*( F_3_A_O_N + F_3_A_O_S + F_4_A_O_N + F_4_A_O_S + F_5_A_O_N ))
 
    # plant B Overtime Labor Cost (Period 1,2)
    - 16.50*(9.1*( W_1_B_O_N + W_1_B_O_S + W_2_B_O_N + W_2_B_O_S ) + 7.8*( G_1_B_O_N + G_1_B_O_S + G_2_B_O_N + G_2_B_O_S ) + 10.6*( F_1_B_O_N + F_1_B_O_S + F_2_B_O_N + F_2_B_O_S ))
    # plant B Overtime Labor Cost (Period 3,4,5)
    - (16.50*1.1)*(9.1*( W_3_B_O_N + W_3_B_O_S + W_4_B_O_N + W_4_B_O_S + W_5_B_O_N ) + 7.8*( G_3_B_O_N + G_3_B_O_S + G_4_B_O_N + G_4_B_O_S + G_5_B_O_N ) + 10.6*( F_3_B_O_N + F_3_B_O_S + F_4_B_O_N + F_4_B_O_S + F_5_B_O_N ))
  
    # plant A Transpotation Cost (Widgets)
    - 6.30*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S + W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S + W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S + W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S + W_5_A_R_N + W_5_A_O_N )
    # plant A Transpotation Cost (Gadgets)
    - 4.60*( G_1_A_R_N + G_1_A_R_S + G_1_A_O_N + G_1_A_O_S + G_2_A_R_N + G_2_A_R_S + G_2_A_O_N + G_2_A_O_S + G_3_A_R_N + G_3_A_R_S + G_3_A_O_N + G_3_A_O_S + G_4_A_R_N + G_4_A_R_S + G_4_A_O_N + G_4_A_O_S + G_5_A_R_N + G_5_A_O_N )
    # plant A Transpotation Cost (Flugels)
    - 5.50*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S + F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S + F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S + F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S + F_5_A_R_N + F_5_A_O_N )
   
    # plant B Transpotation Cost (Widgets)
    - 6.50*( W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S + W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S + W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S + W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S + W_5_B_R_N + W_5_B_O_N )
    # plant B Transpotation Cost (Gadgets)
    - 5.00*( G_1_B_R_N + G_1_B_R_S + G_1_B_O_N + G_1_B_O_S + G_2_B_R_N + G_2_B_R_S + G_2_B_O_N + G_2_B_O_S + G_3_B_R_N + G_3_B_R_S + G_3_B_O_N + G_3_B_O_S + G_4_B_R_N + G_4_B_R_S + G_4_B_O_N + G_4_B_O_S + G_5_B_R_N + G_5_B_O_N )
    # plant B Transpotation Cost (Flugels)
    - 5.70*( F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S + F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S + F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S + F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S + F_5_B_R_N + F_5_B_O_N )
   
    # plant A Raw Material 1 costs
    - 1.25*( 194*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S + W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S + W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S + W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S + W_5_A_R_N + W_5_A_O_N ) + 230*( G_1_A_R_N + G_1_A_R_S + G_1_A_O_N + G_1_A_O_S + G_2_A_R_N + G_2_A_R_S + G_2_A_O_N + G_2_A_O_S + G_3_A_R_N + G_3_A_R_S + G_3_A_O_N + G_3_A_O_S + G_4_A_R_N + G_4_A_R_S + G_4_A_O_N + G_4_A_O_S + G_5_A_R_N + G_5_A_O_N ) +	178*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S + F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S + F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S + F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S + F_5_A_R_N + F_5_A_O_N ))
    # plant A Raw Material 2 costs
    - 2.65*( 8.6*( W_1_A_R_N + W_1_A_R_S + W_1_A_O_N + W_1_A_O_S + W_2_A_R_N + W_2_A_R_S + W_2_A_O_N + W_2_A_O_S + W_3_A_R_N + W_3_A_R_S + W_3_A_O_N + W_3_A_O_S + W_4_A_R_N + W_4_A_R_S + W_4_A_O_N + W_4_A_O_S + W_5_A_R_N + W_5_A_O_N ) + 11.6*( F_1_A_R_N + F_1_A_R_S + F_1_A_O_N + F_1_A_O_S + F_2_A_R_N + F_2_A_R_S + F_2_A_O_N + F_2_A_O_S + F_3_A_R_N + F_3_A_R_S + F_3_A_O_N + F_3_A_O_S + F_4_A_R_N + F_4_A_R_S + F_4_A_O_N + F_4_A_O_S + F_5_A_R_N + F_5_A_O_N ))
  
    # plant B Raw Material 1 costs
    - 1.45*( 188*( W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S + W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S + W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S + W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S + W_5_B_R_N  + W_5_B_O_N ) +	225*( G_1_B_R_N + G_1_B_R_S + G_1_B_O_N + G_1_B_O_S + G_2_B_R_N + G_2_B_R_S + G_2_B_O_N + G_2_B_O_S + G_3_B_R_N + G_3_B_R_S + G_3_B_O_N + G_3_B_O_S + G_4_B_R_N + G_4_B_R_S + G_4_B_O_N + G_4_B_O_S + G_5_B_R_N + G_5_B_O_N ) +	170*( F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S + F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S + F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S + F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S + F_5_B_R_N + F_5_B_O_N ))
    # plant B Raw Material 2 costs
    - 2.90*( 9.2*( W_1_B_R_N + W_1_B_R_S + W_1_B_O_N + W_1_B_O_S + W_2_B_R_N + W_2_B_R_S + W_2_B_O_N + W_2_B_O_S + W_3_B_R_N + W_3_B_R_S + W_3_B_O_N + W_3_B_O_S + W_4_B_R_N + W_4_B_R_S + W_4_B_O_N + W_4_B_O_S + W_5_B_R_N + W_5_B_O_N ) + 10.8*( F_1_B_R_N + F_1_B_R_S + F_1_B_O_N + F_1_B_O_S + F_2_B_R_N + F_2_B_R_S + F_2_B_O_N + F_2_B_O_S + F_3_B_R_N + F_3_B_R_S + F_3_B_O_N + F_3_B_O_S + F_4_B_R_N + F_4_B_R_S + F_4_B_O_N + F_4_B_O_S + F_5_B_R_N + F_5_B_O_N ))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/pulp/pulp.py:1704: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")

# %%
status = prob.solve()

print(f"status={LpStatus[status]}")
print()

# Print Results
for variable in prob.variables():
    print(f"{variable.name} = {variable.varValue}")
print(f"")    
print(f"Objective = {value(prob.objective)}")
print(f"")

# Printing Reduced Costs
for v in prob.variables():
    print (v.name, "=", v.varValue, "\tReduced Cost =", v.dj)
print(f"")

# Printing Shadow Prices
o = [{'name':name, 'shadow price':c.pi, 'slack':c.slack}
    for name, c in prob.constraints.items()]
print(pd.DataFrame(o))
print(f"")
# Out:
# status=Optimal
#
# F_1_A_O_N = 0.0
# F_1_A_O_S = 0.0
# F_1_A_R_N = 0.0
# F_1_A_R_S = 0.0
# F_1_B_O_N = 0.0
# F_1_B_O_S = 0.0
# F_1_B_R_N = 140.0
# F_1_B_R_S = 0.0
# F_1_K = 181.48148
# F_2_A_O_N = 0.0
# F_2_A_O_S = 0.0
# F_2_A_R_N = 0.0
# F_2_A_R_S = 0.0
# F_2_B_O_N = 0.0
# F_2_B_O_S = 0.0
# F_2_B_R_N = 356.48148
# F_2_B_R_S = 0.0
# F_2_K = 96.937522
# F_3_A_O_N = 0.0
# F_3_A_O_S = 0.0
# F_3_A_R_N = 0.0
# F_3_A_R_S = 0.0
# F_3_B_O_N = 0.0
# F_3_B_O_S = 0.0
# F_3_B_R_N = 301.93752
# F_3_B_R_S = 0.0
# F_3_K = 44.115789
# F_4_A_O_N = 0.0
# F_4_A_O_S = 0.0
# F_4_A_R_N = 0.0
# F_4_A_R_S = 0.0
# F_4_B_O_N = 15.014002
# F_4_B_O_S = 0.0
# F_4_B_R_N = 264.10179
# F_4_B_R_S = 0.0
# F_4_K = 44.689783
# F_5_A_O_N = 0.0
# F_5_A_R_N = 0.0
# F_5_B_O_N = 15.964858
# F_5_B_R_N = 258.72493
# G_1_A_O_N = 0.0
# G_1_A_O_S = 0.0
# G_1_A_R_N = 200.0
# G_1_A_R_S = 70.0
# G_1_B_O_N = 0.0
# G_1_B_O_S = 0.0
# G_1_B_R_N = 0.0
# G_1_B_R_S = 50.0
# G_1_K = 0.0
# G_2_A_O_N = 0.0
# G_2_A_O_S = 0.0
# ...
